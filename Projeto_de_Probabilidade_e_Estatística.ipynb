# %%
#Rode este se possuir o banco de dados de nome 'Resultados' com todas as tabelas
#com seus correspondentes dados
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import psycopg2 as psy

host = 'localhost'
port = '5432'
dbname = 'Resultados'
user = 'postgres'
password = 'yourSecretPassword'

tbnameI51k = 'Resultados_1k_intel5_11400H_16GBRAM'
tbnameI510k = 'Resultados_10k_intel5_11400H_16GBRAM'
tbnameI5100k = 'Resultados_100k_intel5_11400H_16GBRAM'
tbnameI710k = 'Resultados_10k_intel7_11700_32GBRAM'
tbnameI7100k = 'Resultados_100k_intel7_11700_32GBRAM'
tbnameR710k = 'Resultados_10k_Ryzen7_3700U_8GBRAM'
tbnameR7100k = 'Resultados_100k_Ryzen7_3700U_8GBRAM'
connection = psy.connect(f"host='{host}' port='{port}' dbname='{dbname}' user='{user}' password='{password}'")

DF1i5114 = pd.read_sql_query("select * from {}".format(tbnameI51k), con=connection)
DF10i5114 = pd.read_sql_query("select * from {}".format(tbnameI510k), con=connection)
DF100i5114 = pd.read_sql_query("select * from {}".format(tbnameI5100k), con=connection)
DF10i7117 = pd.read_sql_query("select * from {}".format(tbnameI710k), con=connection)
DF100i7117 = pd.read_sql_query("select * from {}".format(tbnameI7100k), con=connection)
DF10r737 = pd.read_sql_query("select * from {}".format(tbnameR710k), con=connection)
DF100r737 = pd.read_sql_query("select * from {}".format(tbnameR7100k), con=connection)

print("Ryzen7100K\n", DF100r737, "\n\n")
print("Intel5100K\n", DF100i5114, "\n\n")
print("Intel7100K\n", DF100i7117, "\n\n")
print("Ryzen710K\n", DF10r737, "\n\n")
print("Intel510K\n", DF10i5114, "\n\n")
print("Intel710K\n", DF10i7117, "\n\n")
print("Intel51K\n", DF1i5114, "\n\n")

# %%
#Rode este se possuir somente os .csv no workspace no colab/jupyter
#ou todos os arquivos na mesma pasta na hora da execução
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

Resultados_100k_Ryzen7_3700U_8GBRAM = pd.read_csv(r'Resultados_100k_Ryzen7_3700U_8GBRAM.csv')
DF100r737 = pd.DataFrame(Resultados_100k_Ryzen7_3700U_8GBRAM)

Resultados_100k_intel5_11400H_16GBRAM = pd.read_csv(r'Resultados_100k_intel5_11400H_16GBRAM.csv')
DF100i5114 = pd.DataFrame(Resultados_100k_intel5_11400H_16GBRAM)

Resultados_100k_intel7_11700_32GBRAM = pd.read_csv(r'Resultados_100k_intel7_11700_32GBRAM.csv')
DF100i7117 = pd.DataFrame(Resultados_100k_intel7_11700_32GBRAM)

Resultados_10k_Ryzen7_3700U_8GBRAM = pd.read_csv(r'Resultados_10k_Ryzen7_3700U_8GBRAM.csv')
DF10r737 = pd.DataFrame(Resultados_10k_Ryzen7_3700U_8GBRAM)

Resultados_10k_intel5_11400H_16GBRAM = pd.read_csv(r'Resultados_10k_intel5_11400H_16GBRAM.csv')
DF10i5114 = pd.DataFrame(Resultados_10k_intel5_11400H_16GBRAM)

Resultados_10k_intel7_11700_32GBRAM = pd.read_csv(r'Resultados_10k_intel7_11700_32GBRAM.csv')
DF10i7117 = pd.DataFrame(Resultados_10k_intel7_11700_32GBRAM)

Resultados_1k_intel5_11400H_16GBRAM = pd.read_csv(r'Resultados_1k_intel5_11400H_16GBRAM.csv')
DF1i5114 = pd.DataFrame(Resultados_1k_intel5_11400H_16GBRAM)

print("Ryzen7100K\n", DF100r737, "\n\n")
print("Intel5100K\n", DF100i5114, "\n\n")
print("Intel7100K\n", DF100i7117, "\n\n")
print("Ryzen710K\n", DF10r737, "\n\n")
print("Intel510K\n", DF10i5114, "\n\n")
print("Intel710K\n", DF10i7117, "\n\n")
print("Intel51K\n", DF1i5114, "\n\n")
# Out:
# Ryzen7100K
#       BubbleSort   QuickSort   MergeSort
# 0        82.696       0.135       0.037
# 1        57.699       0.140       0.037
# 2        54.907       0.121       0.033
# 3        54.393       0.125       0.031
# 4        54.832       0.127       0.032
# ..          ...         ...         ...
# 995      53.496       0.133       0.040
# 996      53.617       0.124       0.030
# 997      53.962       0.125       0.031
# 998      53.930       0.121       0.032
# 999      54.247       0.136       0.036
#
# [1000 rows x 3 columns]
#
#
# Intel5100K
#       BubbleSort   QuickSort   MergeSort
# 0        28.928       0.095       0.021
# 1        29.095       0.096       0.019
# 2        28.934       0.095       0.020
# 3        28.981       0.097       0.019
# 4        28.983       0.096       0.019
# ..          ...         ...         ...
# 995      29.050       0.095       0.019
# 996      29.033       0.096       0.018
# 997      29.008       0.096       0.019
# ...

# %%
#RESULTADOS 100K RYZEN7 3700U 8GBRAM
total = DF100r737[DF100r737.columns[0]].count()                            #numero total de valores
DF100r737_media_Bubble = round(np.average(DF100r737['BubbleSort']), 3)     #media
DF100r737_variancia_Bubble = round(np.var(DF100r737['BubbleSort']), 3)     #variancia
DF100r737_desvioPadrao_Bubble = round(np.std(DF100r737['BubbleSort']), 3)  #desvio padrao
print("Resultados 100K Ryzen7, população:", total,"\n")
print("BubbleSort")
print("Media         :", DF100r737_media_Bubble)
print("Variância     :", DF100r737_variancia_Bubble)
print("Desvio padrao :", DF100r737_desvioPadrao_Bubble)
DF100r737_media_Quick= round(np.average(DF100r737[' QuickSort']), 4)
DF100r737_variancia_Quick = round(np.var(DF100r737[' QuickSort']), 4)
DF100r737_desvioPadrao_Quick = round(np.std(DF100r737[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF100r737_media_Quick)
print("Variância     :", DF100r737_variancia_Quick)
print("Desvio padrao :", DF100r737_desvioPadrao_Quick)
DF100r737_media_Merge= round(np.average(DF100r737[' MergeSort']), 4)
DF100r737_variancia_Merge = round(np.var(DF100r737[' MergeSort']), 4)
DF100r737_desvioPadrao_Merge = round(np.std(DF100r737[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF100r737_media_Merge)
print("Variância     :", DF100r737_variancia_Merge)
print("Desvio padrao :", DF100r737_desvioPadrao_Merge)

#quantidade para a amostra da populacao
total_amostra = 100
print("\nResultados 100K Ryzen7, amostra:", total_amostra,"\n")
DF100r737_amostra = DF100r737.sample(total_amostra)
DF100r737_amostra_media_Bubble = round(np.average(DF100r737_amostra['BubbleSort']), 3)     #media
DF100r737_amostra_variancia_Bubble = round(np.var(DF100r737_amostra['BubbleSort']), 3)     #variancia
DF100r737_amostra_desvioPadrao_Bubble = round(np.std(DF100r737_amostra['BubbleSort']), 3)  #desvio padrao
print("BubbleSort")
print("Media         :", DF100r737_amostra_media_Bubble)
print("Variância     :", DF100r737_amostra_variancia_Bubble)
print("Desvio padrao :", DF100r737_amostra_desvioPadrao_Bubble)
ic_Bubble_amostra = 1.96*(DF100r737_amostra_desvioPadrao_Bubble/math.sqrt(total))          #calculo do intervalo de confianca
print("\nIntervalo de confianca 95% +-", round(ic_Bubble_amostra, 3))
print("[", round((DF100r737_amostra_media_Bubble-ic_Bubble_amostra), 3), ";", DF100r737_amostra_media_Bubble, ";", round((DF100r737_amostra_media_Bubble+ic_Bubble_amostra), 3), "]")
ic2_Bubble_amostra = 1.282*(DF100r737_amostra_desvioPadrao_Bubble/math.sqrt(total))          #calculo do intervalo de confianca
print("\nIntervalo de confianca 80% +-", round(ic2_Bubble_amostra, 3))
print("[", round((DF100r737_amostra_media_Bubble-ic2_Bubble_amostra), 3), ";", DF100r737_amostra_media_Bubble, ";", round((DF100r737_amostra_media_Bubble+ic2_Bubble_amostra), 3), "]")
DF100r737_amostra_media_Quick= round(np.average(DF100r737_amostra[' QuickSort']), 4)
DF100r737_amostra_variancia_Quick = round(np.var(DF100r737_amostra[' QuickSort']), 4)
DF100r737_amostra_desvioPadrao_Quick = round(np.std(DF100r737_amostra[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF100r737_amostra_media_Quick)
print("Variância     :", DF100r737_amostra_variancia_Quick)
print("Desvio padrao :", DF100r737_amostra_desvioPadrao_Quick)
ic_Quick_amostra = 1.96*(DF100r737_desvioPadrao_Quick/math.sqrt(total))
print("\nIntervalo de confianca +-", round(ic_Quick_amostra, 4))
print("[", round((DF100r737_amostra_media_Quick-ic_Quick_amostra), 4), ";", DF100r737_amostra_media_Quick, ";", round((DF100r737_amostra_media_Quick+ic_Quick_amostra), 4), "]")
DF100r737_amostra_media_Merge= round(np.average(DF100r737_amostra[' MergeSort']), 4)
DF100r737_amostra_variancia_Merge = round(np.var(DF100r737_amostra[' MergeSort']), 4)
DF100r737_amostra_desvioPadrao_Merge = round(np.std(DF100r737_amostra[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF100r737_amostra_media_Merge)
print("Variância     :", DF100r737_amostra_variancia_Merge)
print("Desvio padrao :", DF100r737_amostra_desvioPadrao_Merge)
ic_Merge_amostra = 1.96*(DF100r737_desvioPadrao_Merge/math.sqrt(total))
print("\nIntervalo de confianca +-", round(ic_Merge_amostra, 4))
print("[", round((DF100r737_amostra_media_Merge-ic_Merge_amostra), 4), ";", DF100r737_amostra_media_Merge, ";", round((DF100r737_amostra_media_Merge+ic_Merge_amostra), 4), "]")

plt.boxplot(DF100r737['BubbleSort'], vert=0)
# Out:
# Resultados 100K Ryzen7, população: 1000
#
# BubbleSort
# Media         : 55.077
# Variância     : 4.456
# Desvio padrao : 2.111
#
# QuickSort
# Media         : 0.1293
# Variância     : 0.0001
# Desvio padrao : 0.0087
#
# MergeSort
# Media         : 0.033
# Variância     : 0.0
# Desvio padrao : 0.0031
#
# Resultados 100K Ryzen7, amostra: 100
#
# BubbleSort
# Media         : 55.027
# Variância     : 3.81
# Desvio padrao : 1.952
#
# Intervalo de confianca 95% +- 0.121
# [ 54.906 ; 55.027 ; 55.148 ]
#
# Intervalo de confianca 80% +- 0.079
# [ 54.948 ; 55.027 ; 55.106 ]
#
# QuickSort
# Media         : 0.1294
# Variância     : 0.0001
# Desvio padrao : 0.0078
#
# Intervalo de confianca +- 0.0005
# [ 0.1289 ; 0.1294 ; 0.1299 ]
#
# MergeSort
# Media         : 0.0328
# Variância     : 0.0
# Desvio padrao : 0.0028
#
# Intervalo de confianca +- 0.0002
# [ 0.0326 ; 0.0328 ; 0.033 ]
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d2badd296f0>,
# ...

# %%
#RESULTADOS 100K intel5 11400H 16GBRAM
total = DF100i5114[DF100i5114.columns[0]].count()                            #numero total de valores
DF100i5114_media_Bubble = round(np.average(DF100i5114['BubbleSort']), 3)     #media
DF100i5114_variancia_Bubble = round(np.var(DF100i5114['BubbleSort']), 3)     #variancia
DF100i5114_desvioPadrao_Bubble = round(np.std(DF100i5114['BubbleSort']), 3)  #desvio padrao
print("Resultados 100K intel5\n")
print("BubbleSort")
print("Media         :", DF100i5114_media_Bubble)
print("Variancia     :", DF100i5114_variancia_Bubble)
print("Desvio padrao :", DF100i5114_desvioPadrao_Bubble)
DF100i5114_media_Quick= round(np.average(DF100i5114[' QuickSort']), 4)
DF100i5114_variancia_Quick = round(np.var(DF100i5114[' QuickSort']), 4)
DF100i5114_desvioPadrao_Quick = round(np.std(DF100i5114[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF100i5114_media_Quick)
print("Variancia     :", DF100i5114_variancia_Quick)
print("Desvio padrao :", DF100i5114_desvioPadrao_Quick)
DF100i5114_media_Merge= round(np.average(DF100i5114[' MergeSort']), 4)
DF100i5114_variancia_Merge = round(np.var(DF100i5114[' MergeSort']), 4)
DF100i5114_desvioPadrao_Merge = round(np.std(DF100i5114[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF100i5114_media_Merge)
print("Variancia     :", DF100i5114_variancia_Merge)
print("Desvio padrao :", DF100i5114_desvioPadrao_Merge)

#quantidade para a amostra da populacao
total_amostra = 1000
print("\nResultados 100K Intel5, amostra:", total_amostra,"\n")
DF100i5114_amostra = DF100i5114.sample(total_amostra)
DF100i5114_amostra_media_Bubble = round(np.average(DF100i5114_amostra['BubbleSort']), 3)     #media
DF100i5114_amostra_variancia_Bubble = round(np.var(DF100i5114_amostra['BubbleSort']), 3)     #variancia
DF100i5114_amostra_desvioPadrao_Bubble = round(np.std(DF100i5114_amostra['BubbleSort']), 3)  #desvio padrao
print("BubbleSort")
print("Media         :", DF100i5114_amostra_media_Bubble)
print("Variância     :", DF100i5114_amostra_variancia_Bubble)
print("Desvio padrao :", DF100i5114_amostra_desvioPadrao_Bubble)
ic_Bubble_amostra = 1.96*(DF100i5114_amostra_desvioPadrao_Bubble/math.sqrt(total))          #calculo do intervalo de confianca
print("\nIntervalo de confianca +-", round(ic_Bubble_amostra, 3))
print("[", round((DF100i5114_amostra_media_Bubble-ic_Bubble_amostra), 3), ";", DF100i5114_amostra_media_Bubble, ";", round((DF100i5114_amostra_media_Bubble+ic_Bubble_amostra), 3), "]")
DF100i5114_amostra_media_Quick= round(np.average(DF100i5114_amostra[' QuickSort']), 4)
DF100i5114_amostra_variancia_Quick = round(np.var(DF100i5114_amostra[' QuickSort']), 4)
DF100i5114_amostra_desvioPadrao_Quick = round(np.std(DF100i5114_amostra[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF100i5114_amostra_media_Quick)
print("Variância     :", DF100i5114_amostra_variancia_Quick)
print("Desvio padrao :", DF100i5114_amostra_desvioPadrao_Quick)
ic_Quick_amostra = 1.96*(DF100i5114_desvioPadrao_Quick/math.sqrt(total))
print("\nIntervalo de confianca +-", round(ic_Quick_amostra, 4))
print("[", round((DF100i5114_amostra_media_Quick-ic_Quick_amostra), 4), ";", DF100i5114_amostra_media_Quick, ";", round((DF100i5114_amostra_media_Quick+ic_Quick_amostra), 4), "]")
DF100i5114_amostra_media_Merge= round(np.average(DF100i5114_amostra[' MergeSort']), 4)
DF100i5114_amostra_variancia_Merge = round(np.var(DF100i5114_amostra[' MergeSort']), 4)
DF100i5114_amostra_desvioPadrao_Merge = round(np.std(DF100i5114_amostra[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF100i5114_amostra_media_Merge)
print("Variância     :", DF100i5114_amostra_variancia_Merge)
print("Desvio padrao :", DF100i5114_amostra_desvioPadrao_Merge)
ic_Merge_amostra = 1.96*(DF100i5114_desvioPadrao_Merge/math.sqrt(total))
print("\nIntervalo de confianca +-", round(ic_Merge_amostra, 4))
print("[", round((DF100i5114_amostra_media_Merge-ic_Merge_amostra), 4), ";", DF100i5114_amostra_media_Merge, ";", round((DF100i5114_amostra_media_Merge+ic_Merge_amostra), 4), "]")
# Out:
# Resultados 100K intel5
#
# BubbleSort
# Media         : 29.027
# Variancia     : 0.025
# Desvio padrao : 0.159
#
# QuickSort
# Media         : 0.0961
# Variancia     : 0.0
# Desvio padrao : 0.0014
#
# MergeSort
# Media         : 0.0193
# Variancia     : 0.0
# Desvio padrao : 0.0009
#
# Resultados 100K Intel5, amostra: 1000
#
# BubbleSort
# Media         : 29.027
# Variância     : 0.025
# Desvio padrao : 0.159
#
# Intervalo de confianca +- 0.01
# [ 29.017 ; 29.027 ; 29.037 ]
#
# QuickSort
# Media         : 0.0961
# Variância     : 0.0
# Desvio padrao : 0.0014
#
# Intervalo de confianca +- 0.0001
# [ 0.096 ; 0.0961 ; 0.0962 ]
#
# MergeSort
# Media         : 0.0193
# Variância     : 0.0
# Desvio padrao : 0.0009
#
# Intervalo de confianca +- 0.0001
# [ 0.0192 ; 0.0193 ; 0.0194 ]

# %%
#RESULTADOS 100K intel7 11700 32GBRAM
total = DF100i7117[DF100i7117.columns[0]].count()                            #numero total de valores
DF100i7117_media_Bubble = round(np.average(DF100i7117['BubbleSort']), 3)     #media
DF100i7117_variancia_Bubble = round(np.var(DF100i7117['BubbleSort']), 3)     #variancia
DF100i7117_desvioPadrao_Bubble = round(np.std(DF100i7117['BubbleSort']), 3)  #desvio padrao
print("Resultados 100K intel7\n")
print("BubbleSort")
print("Media         :", DF100i7117_media_Bubble)
print("Variancia     :", DF100i7117_variancia_Bubble)
print("Desvio padrao :", DF100i7117_desvioPadrao_Bubble)
DF100i7117_media_Quick= round(np.average(DF100i7117[' QuickSort']), 4)
DF100i7117_variancia_Quick = round(np.var(DF100i7117[' QuickSort']), 4)
DF100i7117_desvioPadrao_Quick = round(np.std(DF100i7117[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF100i7117_media_Quick)
print("Variancia     :", DF100i7117_variancia_Quick)
print("Desvio padrao :", DF100i7117_desvioPadrao_Quick)
DF100i7117_media_Merge= round(np.average(DF100i7117[' MergeSort']), 4)
DF100i7117_variancia_Merge = round(np.var(DF100i7117[' MergeSort']), 4)
DF100i7117_desvioPadrao_Merge = round(np.std(DF100i7117[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF100i7117_media_Merge)
print("Variancia     :", DF100i7117_variancia_Merge)
print("Desvio padrao :", DF100i7117_desvioPadrao_Merge)

#quantidade para a amostra da populacao
total_amostra = 1000
print("\nResultados 100K Intel7, amostra:", total_amostra,"\n")
DF100i7117_amostra = DF100i7117.sample(total_amostra)
DF100i7117_amostra_media_Bubble = round(np.average(DF100i7117_amostra['BubbleSort']), 3)     #media
DF100i7117_amostra_variancia_Bubble = round(np.var(DF100i7117_amostra['BubbleSort']), 3)     #variancia
DF100i7117_amostra_desvioPadrao_Bubble = round(np.std(DF100i7117_amostra['BubbleSort']), 3)  #desvio padrao
print("BubbleSort")
print("Media         :", DF100i7117_amostra_media_Bubble)
print("Variância     :", DF100i7117_amostra_variancia_Bubble)
print("Desvio padrao :", DF100i7117_amostra_desvioPadrao_Bubble)
ic_Bubble_amostra = 1.96*(DF100i7117_amostra_desvioPadrao_Bubble/math.sqrt(total))          #calculo do intervalo de confianca
print("\nIntervalo de confianca +-", round(ic_Bubble_amostra, 3))
print("[", round((DF100i7117_amostra_media_Bubble-ic_Bubble_amostra), 3), ";", DF100i7117_amostra_media_Bubble, ";", round((DF100i7117_amostra_media_Bubble+ic_Bubble_amostra), 3), "]")
DF100i7117_amostra_media_Quick= round(np.average(DF100i7117_amostra[' QuickSort']), 4)
DF100i7117_amostra_variancia_Quick = round(np.var(DF100i7117_amostra[' QuickSort']), 4)
DF100i7117_amostra_desvioPadrao_Quick = round(np.std(DF100i7117_amostra[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF100i7117_amostra_media_Quick)
print("Variância     :", DF100i7117_amostra_variancia_Quick)
print("Desvio padrao :", DF100i7117_amostra_desvioPadrao_Quick)
ic_Quick_amostra = 1.96*(DF100i7117_desvioPadrao_Quick/math.sqrt(total))
print("\nIntervalo de confianca +-", round(ic_Quick_amostra, 4))
print("[", round((DF100i7117_amostra_media_Quick-ic_Quick_amostra), 4), ";", DF100i7117_amostra_media_Quick, ";", round((DF100i7117_amostra_media_Quick+ic_Quick_amostra), 4), "]")
DF100i7117_amostra_media_Merge= round(np.average(DF100i7117_amostra[' MergeSort']), 4)
DF100i7117_amostra_variancia_Merge = round(np.var(DF100i7117_amostra[' MergeSort']), 4)
DF100i7117_amostra_desvioPadrao_Merge = round(np.std(DF100i7117_amostra[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF100i7117_amostra_media_Merge)
print("Variância     :", DF100i7117_amostra_variancia_Merge)
print("Desvio padrao :", DF100i7117_amostra_desvioPadrao_Merge)
ic_Merge_amostra = 1.96*(DF100i7117_desvioPadrao_Merge/math.sqrt(total))
print("\nIntervalo de confianca +-", round(ic_Merge_amostra, 4))
print("[", round((DF100i7117_amostra_media_Merge-ic_Merge_amostra), 4), ";", DF100i7117_amostra_media_Merge, ";", round((DF100i7117_amostra_media_Merge+ic_Merge_amostra), 4), "]")
# Out:
# Resultados 100K intel7
#
# BubbleSort
# Media         : 23.698
# Variancia     : 0.168
# Desvio padrao : 0.41
#
# QuickSort
# Media         : 0.0455
# Variancia     : 0.0
# Desvio padrao : 0.0019
#
# MergeSort
# Media         : 0.0177
# Variancia     : 0.0
# Desvio padrao : 0.0009
#
# Resultados 100K Intel7, amostra: 1000
#
# BubbleSort
# Media         : 23.698
# Variância     : 0.168
# Desvio padrao : 0.41
#
# Intervalo de confianca +- 0.025
# [ 23.673 ; 23.698 ; 23.723 ]
#
# QuickSort
# Media         : 0.0455
# Variância     : 0.0
# Desvio padrao : 0.0019
#
# Intervalo de confianca +- 0.0001
# [ 0.0454 ; 0.0455 ; 0.0456 ]
#
# MergeSort
# Media         : 0.0177
# Variância     : 0.0
# Desvio padrao : 0.0009
#
# Intervalo de confianca +- 0.0001
# [ 0.0176 ; 0.0177 ; 0.0178 ]

# %%
#Visualização de todos os tempos obtidos com 100k dados
plt.plot(DF100r737['BubbleSort'], label = "Ryzen7", linestyle="-")
plt.plot(DF100i5114['BubbleSort'], label = "Intel5", linestyle="--")
plt.plot(DF100i7117['BubbleSort'], label = "Intel7", linestyle="-.")
plt.title("Tempo em segundos BubbleSort com 100k dados")
plt.legend()
plt.show()
plt.plot(DF100r737[' QuickSort'], label = "Ryzen7", linestyle="-")
plt.plot(DF100i5114[' QuickSort'], label = "Intel5", linestyle="--")
plt.plot(DF100i7117[' QuickSort'], label = "Intel7", linestyle="-.")
plt.title("Tempo em segundos QuickSort com 100k dados")
plt.legend()
plt.show()
plt.plot(DF100r737[' MergeSort'], label = "Ryzen7", linestyle="-")
plt.plot(DF100i5114[' MergeSort'], label = "Intel5", linestyle="--")
plt.plot(DF100i7117[' MergeSort'], label = "Intel7", linestyle="-.")
plt.title("Tempo em segundos MergeSort com 100k dados")
plt.legend()
plt.show()

# %%
#Base usada nos cálculos de intervalo de confiança
ic_Bubble = 1.96*(DF100r737_desvioPadrao_Bubble/math.sqrt(total))
print("\nIntervalo de confianca +-", round(ic_Bubble, 3))
print("[", round((DF100r737_media_Bubble-ic_Bubble), 3), ";", DF100r737_media_Bubble, ";", round((DF100r737_media_Bubble+ic_Bubble), 3), "]")
ic_Quick = 1.96*(DF100r737_desvioPadrao_Quick/math.sqrt(total))
print("\nIntervalo de confianca +-", round(ic_Quick, 4))
print("[", round((DF100r737_media_Quick-ic_Quick), 4), ";", DF100r737_media_Quick, ";", round((DF100r737_media_Quick+ic_Quick), 4), "]")
ic_Merge = 1.96*(DF100r737_desvioPadrao_Merge/math.sqrt(total))
print("\nIntervalo de confianca +-", round(ic_Merge, 4))
print("[", round((DF100r737_media_Merge-ic_Merge), 4), ";", DF100r737_media_Merge, ";", round((DF100r737_media_Merge+ic_Merge), 4), "]")
# Out:
# Intervalo de confianca +- 0.131
# [ 54.946 ; 55.077 ; 55.208 ]
#
# Intervalo de confianca +- 0.0005
# [ 0.1288 ; 0.1293 ; 0.1298 ]
#
# Intervalo de confianca +- 0.0002
# [ 0.0328 ; 0.033 ; 0.0332 ]

# %%
todos100k = pd.DataFrame()
todos100k = DF100r737
todos100k = pd.concat([todos100k, DF100i5114], ignore_index=True)
todos100k = pd.concat([todos100k, DF100i7117], ignore_index=True)
print(todos100k)
#RESULTADOS 100K
total = todos100k[todos100k.columns[0]].count()                            #numero total de valores
todos100k_media_Bubble = round(np.average(todos100k['BubbleSort']), 3)     #media
todos100k_variancia_Bubble = round(np.var(todos100k['BubbleSort']), 3)     #variancia
todos100k_desvioPadrao_Bubble = round(np.std(todos100k['BubbleSort']), 3)  #desvio padrao
print("Resultados de todos os 100k, população:", total,"\n")
print("BubbleSort")
print("Media         :", todos100k_media_Bubble)
print("Variância     :", todos100k_variancia_Bubble)
print("Desvio padrao :", todos100k_desvioPadrao_Bubble)
todos100k_media_Quick= round(np.average(todos100k[' QuickSort']), 4)
todos100k_variancia_Quick = round(np.var(todos100k[' QuickSort']), 4)
todos100k_desvioPadrao_Quick = round(np.std(todos100k[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", todos100k_media_Quick)
print("Variância     :", todos100k_variancia_Quick)
print("Desvio padrao :", todos100k_desvioPadrao_Quick)
todos100k_media_Merge= round(np.average(todos100k[' MergeSort']), 4)
todos100k_variancia_Merge = round(np.var(todos100k[' MergeSort']), 4)
todos100k_desvioPadrao_Merge = round(np.std(todos100k[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", todos100k_media_Merge)
print("Variância     :", todos100k_variancia_Merge)
print("Desvio padrao :", todos100k_desvioPadrao_Merge)
# Out:
#       BubbleSort   QuickSort   MergeSort
# 0         82.696       0.135       0.037
# 1         57.699       0.140       0.037
# 2         54.907       0.121       0.033
# 3         54.393       0.125       0.031
# 4         54.832       0.127       0.032
# ...          ...         ...         ...
# 2995      24.070       0.048       0.018
# 2996      24.190       0.045       0.019
# 2997      23.843       0.046       0.017
# 2998      23.714       0.044       0.019
# 2999      23.472       0.049       0.017
#
# [3000 rows x 3 columns]
# Resultados de todos os 100k, população: 3000
#
# BubbleSort
# Media         : 35.934
# Variância     : 189.508
# Desvio padrao : 13.766
#
# QuickSort
# Media         : 0.0903
# Variância     : 0.0012
# Desvio padrao : 0.0348
#
# MergeSort
# Media         : 0.0233
# Variância     : 0.0001
# Desvio padrao : 0.0071

# %%
#RESULTADOS 1K
total = DF1i5114[DF1i5114.columns[0]].count()                            #numero total de valores
DF1i5114_media_Bubble = round(np.average(DF1i5114['BubbleSort']), 3)     #media
DF1i5114_variancia_Bubble = round(np.var(DF1i5114['BubbleSort']), 3)     #variancia
DF1i5114_desvioPadrao_Bubble = round(np.std(DF1i5114['BubbleSort']), 3)  #desvio padrao
print("Resultados de 1k no Intel5-11400H 8GBRAM, população:", total,"\n")
print("BubbleSort")
print("Media         :", DF1i5114_media_Bubble)
print("Variância     :", DF1i5114_variancia_Bubble)
print("Desvio padrao :", DF1i5114_desvioPadrao_Bubble)
DF1i5114_media_Quick= round(np.average(DF1i5114[' QuickSort']), 4)
DF1i5114_variancia_Quick = round(np.var(DF1i5114[' QuickSort']), 4)
DF1i5114_desvioPadrao_Quick = round(np.std(DF1i5114[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF1i5114_media_Quick)
print("Variância     :", DF1i5114_variancia_Quick)
print("Desvio padrao :", DF1i5114_desvioPadrao_Quick)
DF1i5114_media_Merge= round(np.average(DF1i5114[' MergeSort']), 4)
DF1i5114_variancia_Merge = round(np.var(DF1i5114[' MergeSort']), 4)
DF1i5114_desvioPadrao_Merge = round(np.std(DF1i5114[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF1i5114_media_Merge)
print("Variância     :", DF1i5114_variancia_Merge)
print("Desvio padrao :", DF1i5114_desvioPadrao_Merge)
# Out:
# Resultados de 1k no Intel5-11400H 8GBRAM, população: 10000
#
# BubbleSort
# Media         : 0.002
# Variância     : 0.0
# Desvio padrao : 0.0
#
# QuickSort
# Media         : 0.0001
# Variância     : 0.0
# Desvio padrao : 0.0003
#
# MergeSort
# Media         : 0.0002
# Variância     : 0.0
# Desvio padrao : 0.0004

# %%
#RESULTADOS 10K RYZEN7 3700U 8GBRAM
total = DF10r737[DF10r737.columns[0]].count()                            #numero total de valores
DF10r737_media_Bubble = round(np.average(DF10r737['BubbleSort']), 3)     #media
DF10r737_variancia_Bubble = round(np.var(DF10r737['BubbleSort']), 3)     #variancia
DF10r737_desvioPadrao_Bubble = round(np.std(DF10r737['BubbleSort']), 3)  #desvio padrao
print("Resultados 10K Ryzen7\n")
print("BubbleSort")
print("Media         :", DF10r737_media_Bubble)
print("Variancia     :", DF10r737_variancia_Bubble)
print("Desvio padrao :", DF10r737_desvioPadrao_Bubble)
DF10r737_media_Quick= round(np.average(DF10r737[' QuickSort']), 4)
DF10r737_variancia_Quick = round(np.var(DF10r737[' QuickSort']), 4)
DF10r737_desvioPadrao_Quick = round(np.std(DF10r737[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF10r737_media_Quick)
print("Variancia     :", DF10r737_variancia_Quick)
print("Desvio padrao :", DF10r737_desvioPadrao_Quick)
DF10r737_media_Merge= round(np.average(DF10r737[' MergeSort']), 4)
DF10r737_variancia_Merge = round(np.var(DF10r737[' MergeSort']), 4)
DF10r737_desvioPadrao_Merge = round(np.std(DF10r737[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF10r737_media_Merge)
print("Variancia     :", DF10r737_variancia_Merge)
print("Desvio padrao :", DF10r737_desvioPadrao_Merge)
# Out:
# Resultados 10K Ryzen7
#
# BubbleSort
# Media         : 0.49
# Variancia     : 0.001
# Desvio padrao : 0.023
#
# QuickSort
# Media         : 0.0024
# Variancia     : 0.0
# Desvio padrao : 0.0005
#
# MergeSort
# Media         : 0.0031
# Variancia     : 0.0
# Desvio padrao : 0.0005

# %%
#RESULTADOS 10K intel5 11400H 16GBRAM
total = DF10i5114[DF10i5114.columns[0]].count()                            #numero total de valores
DF10i5114_media_Bubble = round(np.average(DF10i5114['BubbleSort']), 3)     #media
DF10i5114_variancia_Bubble = round(np.var(DF10i5114['BubbleSort']), 3)     #variancia
DF10i5114_desvioPadrao_Bubble = round(np.std(DF10i5114['BubbleSort']), 3)  #desvio padrao
print("Resultados 10K intel5\n")
print("BubbleSort")
print("Media         :", DF10i5114_media_Bubble)
print("Variancia     :", DF10i5114_variancia_Bubble)
print("Desvio padrao :", DF10i5114_desvioPadrao_Bubble)
DF10i5114_media_Quick= round(np.average(DF10i5114[' QuickSort']), 4)
DF10i5114_variancia_Quick = round(np.var(DF10i5114[' QuickSort']), 4)
DF10i5114_desvioPadrao_Quick = round(np.std(DF10i5114[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF10i5114_media_Quick)
print("Variancia     :", DF10i5114_variancia_Quick)
print("Desvio padrao :", DF10i5114_desvioPadrao_Quick)
DF10i5114_media_Merge= round(np.average(DF10i5114[' MergeSort']), 4)
DF10i5114_variancia_Merge = round(np.var(DF10i5114[' MergeSort']), 4)
DF10i5114_desvioPadrao_Merge = round(np.std(DF10i5114[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF10i5114_media_Merge)
print("Variancia     :", DF10i5114_variancia_Merge)
print("Desvio padrao :", DF10i5114_desvioPadrao_Merge)
# Out:
# Resultados 10K intel5
#
# BubbleSort
# Media         : 0.245
# Variancia     : 0.0
# Desvio padrao : 0.007
#
# QuickSort
# Media         : 0.0018
# Variancia     : 0.0
# Desvio padrao : 0.0005
#
# MergeSort
# Media         : 0.0019
# Variancia     : 0.0
# Desvio padrao : 0.0005

# %%
#RESULTADOS 10K intel7 11700 32GBRAM
total = DF10i7117[DF10i7117.columns[0]].count()                            #numero total de valores
DF10i7117_media_Bubble = round(np.average(DF10i7117['BubbleSort']), 3)     #media
DF10i7117_variancia_Bubble = round(np.var(DF10i7117['BubbleSort']), 3)     #variancia
DF10i7117_desvioPadrao_Bubble = round(np.std(DF10i7117['BubbleSort']), 3)  #desvio padrao
print("Resultados 10K intel7\n")
print("BubbleSort")
print("Media         :", DF10i7117_media_Bubble)
print("Variancia     :", DF10i7117_variancia_Bubble)
print("Desvio padrao :", DF10i7117_desvioPadrao_Bubble)
DF10i7117_media_Quick= round(np.average(DF10i7117[' QuickSort']), 4)
DF10i7117_variancia_Quick = round(np.var(DF10i7117[' QuickSort']), 4)
DF10i7117_desvioPadrao_Quick = round(np.std(DF10i7117[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", DF10i7117_media_Quick)
print("Variancia     :", DF10i7117_variancia_Quick)
print("Desvio padrao :", DF10i7117_desvioPadrao_Quick)
DF10i7117_media_Merge= round(np.average(DF10i7117[' MergeSort']), 4)
DF10i7117_variancia_Merge = round(np.var(DF10i7117[' MergeSort']), 4)
DF10i7117_desvioPadrao_Merge = round(np.std(DF10i7117[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", DF10i7117_media_Merge)
print("Variancia     :", DF10i7117_variancia_Merge)
print("Desvio padrao :", DF10i7117_desvioPadrao_Merge)
# Out:
# Resultados 10K intel7
#
# BubbleSort
# Media         : 0.179
# Variancia     : 0.0
# Desvio padrao : 0.007
#
# QuickSort
# Media         : 0.001
# Variancia     : 0.0
# Desvio padrao : 0.0032
#
# MergeSort
# Media         : 0.0017
# Variancia     : 0.0
# Desvio padrao : 0.0042

# %%
plt.plot(DF10r737['BubbleSort'], label = "Ryzen7", linestyle="-")
plt.plot(DF10i5114['BubbleSort'], label = "Intel5", linestyle="--")
plt.title("Tempo em segundos BubbleSort com 10k dados")
plt.legend()
plt.show()
plt.plot(DF10r737[' QuickSort'], label = "Ryzen7", linestyle="-")
plt.plot(DF10i5114[' QuickSort'], label = "Intel5", linestyle="--")
plt.title("Tempo em segundos QuickSort com 10k dados")
plt.legend()
plt.show()
plt.plot(DF10r737[' MergeSort'], label = "Ryzen7", linestyle="-")
plt.plot(DF10i5114[' MergeSort'], label = "Intel5", linestyle="--")
plt.title("Tempo em segundos MergeSort com 10k dados")
plt.legend()
plt.show()

# %%
todos10k = pd.DataFrame()
todos10k = DF10r737
todos10k = pd.concat([todos10k, DF10i5114], ignore_index=True)
todos10k = pd.concat([todos10k, DF10i7117], ignore_index=True)
print(todos10k)
#RESULTADOS 10K
total = todos10k[todos10k.columns[0]].count()                            #numero total de valores
todos10k_media_Bubble = round(np.average(todos10k['BubbleSort']), 3)     #media
todos10k_variancia_Bubble = round(np.var(todos10k['BubbleSort']), 3)     #variancia
todos10k_desvioPadrao_Bubble = round(np.std(todos10k['BubbleSort']), 3)  #desvio padrao
print("Resultados de todos os 10k, população:", total,"\n")
print("BubbleSort")
print("Media         :", todos10k_media_Bubble)
print("Variância     :", todos10k_variancia_Bubble)
print("Desvio padrao :", todos10k_desvioPadrao_Bubble)
todos10k_media_Quick= round(np.average(todos10k[' QuickSort']), 4)
todos10k_variancia_Quick = round(np.var(todos10k[' QuickSort']), 4)
todos10k_desvioPadrao_Quick = round(np.std(todos10k[' QuickSort']), 4)
print("\nQuickSort")
print("Media         :", todos10k_media_Quick)
print("Variância     :", todos10k_variancia_Quick)
print("Desvio padrao :", todos10k_desvioPadrao_Quick)
todos10k_media_Merge= round(np.average(todos10k[' MergeSort']), 4)
todos10k_variancia_Merge = round(np.var(todos10k[' MergeSort']), 4)
todos10k_desvioPadrao_Merge = round(np.std(todos10k[' MergeSort']), 4)
print("\nMergeSort")
print("Media         :", todos10k_media_Merge)
print("Variância     :", todos10k_variancia_Merge)
print("Desvio padrao :", todos10k_desvioPadrao_Merge)
# Out:
#        BubbleSort   QuickSort   MergeSort
# 0           0.570       0.002       0.004
# 1           0.537       0.002       0.004
# 2           0.520       0.002       0.004
# 3           0.536       0.003       0.003
# 4           0.490       0.003       0.003
# ...           ...         ...         ...
# 20995       0.172       0.000       0.000
# 20996       0.172       0.000       0.000
# 20997       0.171       0.000       0.000
# 20998       0.172       0.000       0.000
# 20999       0.172       0.000       0.016
#
# [21000 rows x 3 columns]
# Resultados de todos os 10k, população: 21000
#
# BubbleSort
# Media         : 0.358
# Variância     : 0.016
# Desvio padrao : 0.127
#
# QuickSort
# Media         : 0.002
# Variância     : 0.0
# Desvio padrao : 0.0009
#
# MergeSort
# Media         : 0.0025
# Variância     : 0.0
# Desvio padrao : 0.0012

# %%
comparar100k = pd.DataFrame()
comparar100k['R7>I5_BubbleSort'] = np.where((DF100r737['BubbleSort'] < DF100i5114['BubbleSort']), 1, 0)
comparar100k['R7>I7_BubbleSort'] = np.where((DF100r737['BubbleSort'] < DF100i7117['BubbleSort']), 1, 0)
comparar100k['I7>I5_BubbleSort'] = np.where((DF100i7117['BubbleSort'] < DF100i5114['BubbleSort']), 1, 0)
print(comparar100k)
print("\n")
proporcao1 = comparar100k.value_counts('R7>I5_BubbleSort')[0]
proporcao2 = comparar100k.value_counts('R7>I7_BubbleSort')[0]
proporcao3 = comparar100k.value_counts('I7>I5_BubbleSort')[1]
print("Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM:", proporcao1)
print("Vezes em que Intel7 32GBRAM foi melhor que Ryzen7 8GBRAM:", proporcao2)
print("Vezes em que Intel7 32GBRAM foi melhor que Intel5 16GBRAM:", proporcao3)
print("\nDe acordo com a probabilidade proporcional, é indubitável que no BubbleSort contendo 100 mil números de teste: ")
print("Intel7 32GBRAM > Intel5 16GBRAM > Ryzen7 8GBRAM")
# Out:
#      R7>I5_BubbleSort  R7>I7_BubbleSort  I7>I5_BubbleSort
# 0                   0                 0                 1
# 1                   0                 0                 1
# 2                   0                 0                 1
# 3                   0                 0                 1
# 4                   0                 0                 1
# ..                ...               ...               ...
# 995                 0                 0                 1
# 996                 0                 0                 1
# 997                 0                 0                 1
# 998                 0                 0                 1
# 999                 0                 0                 1
#
# [1000 rows x 3 columns]
#
#
# Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM: 1000
# Vezes em que Intel7 32GBRAM foi melhor que Ryzen7 8GBRAM: 1000
# Vezes em que Intel7 32GBRAM foi melhor que Intel5 16GBRAM: 1000
#
# ...

# %%
comparar100k = pd.DataFrame()
comparar100k['R7>I5_QuickSort'] = np.where((DF100r737[' QuickSort'] < DF100i5114[' QuickSort']), 1, 0)
comparar100k['R7>I7_QuickSort'] = np.where((DF100r737[' QuickSort'] < DF100i7117[' QuickSort']), 1, 0)
comparar100k['I7>I5_QuickSort'] = np.where((DF100i7117[' QuickSort'] < DF100i5114[' QuickSort']), 1, 0)
print(comparar100k)
print("\n")
proporcao1 = comparar100k.value_counts('R7>I5_QuickSort')[0]
proporcao2 = comparar100k.value_counts('R7>I7_QuickSort')[0]
proporcao3 = comparar100k.value_counts('I7>I5_QuickSort')[1]
print("Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM:", proporcao1)
print("Vezes em que Intel7 32GBRAM foi melhor que Ryzen7 8GBRAM:", proporcao2)
print("Vezes em que Intel7 32GBRAM foi melhor que Intel5 16GBRAM:", proporcao3)
print("\nDe acordo com a probabilidade proporcional, é indubitável que no QuickSort contendo 100 mil números de teste: ")
print("Intel7 32GBRAM > Intel5 16GBRAM > Ryzen7 8GBRAM")
# Out:
#      R7>I5_QuickSort  R7>I7_QuickSort  I7>I5_QuickSort
# 0                  0                0                1
# 1                  0                0                1
# 2                  0                0                1
# 3                  0                0                1
# 4                  0                0                1
# ..               ...              ...              ...
# 995                0                0                1
# 996                0                0                1
# 997                0                0                1
# 998                0                0                1
# 999                0                0                1
#
# [1000 rows x 3 columns]
#
#
# Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM: 1000
# Vezes em que Intel7 32GBRAM foi melhor que Ryzen7 8GBRAM: 1000
# Vezes em que Intel7 32GBRAM foi melhor que Intel5 16GBRAM: 1000
#
# ...

# %%
comparar100k = pd.DataFrame()
comparar100k['R7>I5_MergeSort'] = np.where((DF100r737[' MergeSort'] < DF100i5114[' MergeSort']), 1, 0)
comparar100k['R7>I7_MergeSort'] = np.where((DF100r737[' MergeSort'] < DF100i7117[' MergeSort']), 1, 0)
comparar100k['I7>I5_MergeSort'] = np.where((DF100i7117[' MergeSort'] < DF100i5114[' MergeSort']), 1, 0)
print(comparar100k)
print("\n")
proporcao1 = comparar100k.value_counts('R7>I5_MergeSort')[0]
proporcao2 = comparar100k.value_counts('R7>I7_MergeSort')[0]
proporcao3 = comparar100k.value_counts('I7>I5_MergeSort')[1]
print("Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM:", proporcao1)
print("Vezes em que Intel7 32GBRAM foi melhor que Ryzen7 8GBRAM:", proporcao2)
print("Vezes em que Intel7 32GBRAM foi melhor que Intel5 16GBRAM:", proporcao3)
#teste de hipotese I7 > I5
#h0: p = 0.5 ; h1: p > 0.5
y = comparar100k.value_counts('I7>I5_MergeSort')[1]
n = comparar100k[comparar100k.columns[0]].count()
a = 0.05 #nivel de significancia 5% = 0.05
p = 0.5
#Devido a amostra ser um valor grande, faremos o teste para ver se e possivel usar distribuicao normal
#n*p0 >= 5 e n*(1-p0) >= 5
#1000*0.5 = 500 e 1000*(1-0.5) = 500
#é preciso tambem fazer um ajuste ao valor de y quando se usar dist normal
#y-0.5 , y > n*p0
#y+0.5 , y < n*p0
yl = y-0.5
z = (yl - n*p)/math.sqrt(n*p*(1-p))
print("\n", z, "~=", round(z,2))
print("a = 5% = 0.05")
print("Quanto maior o valor de z, mais o resultado da tabela de distribuição normal se aproxima de zero. Então")
print("z < a")
print("Isso nos leva a concluir que os dados não estão de acordo com h0, ou seja, o Intel7 é mais rápido que o Intel5")
print("\nDe acordo com a probabilidade proporcional, é indubitável que no MergeSort contendo 100 mil números de teste: ")
print("Intel7 32GBRAM > Intel5 16GBRAM > Ryzen7 8GBRAM")
# Out:
#      R7>I5_MergeSort  R7>I7_MergeSort  I7>I5_MergeSort
# 0                  0                0                1
# 1                  0                0                0
# 2                  0                0                1
# 3                  0                0                0
# 4                  0                0                1
# ..               ...              ...              ...
# 995                0                0                1
# 996                0                0                0
# 997                0                0                1
# 998                0                0                0
# 999                0                0                1
#
# [1000 rows x 3 columns]
#
#
# Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM: 1000
# Vezes em que Intel7 32GBRAM foi melhor que Ryzen7 8GBRAM: 1000
# Vezes em que Intel7 32GBRAM foi melhor que Intel5 16GBRAM: 905
#
#  25.58282627076219 ~= 25.58
# a = 5% = 0.05
# ...

# %%
comparar10k = pd.DataFrame()
comparar10k['R7>I5_BubbleSort'] = np.where((DF10r737['BubbleSort'] < DF10i5114['BubbleSort']), 1, 0)
print(comparar10k)
print("\n")
proporcao1 = comparar10k.value_counts('R7>I5_BubbleSort')[0]
print("Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM:", proporcao1)
print("\nDe acordo com a probabilidade proporcional, é indubitável que no BubbleSort contendo 10 mil números de teste: ")
print("Intel5 16GBRAM > Ryzen7 8GBRAM")
# Out:
#       R7>I5_BubbleSort
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 9995                 0
# 9996                 0
# 9997                 0
# 9998                 0
# 9999                 0
#
# [10000 rows x 1 columns]
#
#
# Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM: 10000
#
# De acordo com a probabilidade proporcional, é indubitável que no BubbleSort contendo 10 mil números de teste:
# Intel5 16GBRAM > Ryzen7 8GBRAM

# %%
comparar10k = pd.DataFrame()
comparar10k['R7>I5_QuickSort'] = np.where((DF10r737[' QuickSort'] < DF10i5114[' QuickSort']), 1, 0)
print(comparar10k)
print("\n")
proporcao1 = comparar10k.value_counts('R7>I5_QuickSort')[0]
print("Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM:", proporcao1)
print("\nDe acordo com a probabilidade proporcional, é indubitável que no QuickSort contendo 10 mil números de teste: ")
print("Intel5 16GBRAM > Ryzen7 8GBRAM")
# Out:
#       R7>I5_QuickSort
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 9995                0
# 9996                0
# 9997                0
# 9998                0
# 9999                0
#
# [10000 rows x 1 columns]
#
#
# Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM: 9730
#
# De acordo com a probabilidade proporcional, é indubitável que no QuickSort contendo 10 mil números de teste:
# Intel5 16GBRAM > Ryzen7 8GBRAM

# %%
comparar10k = pd.DataFrame()
comparar10k['R7>I5_MergeSort'] = np.where((DF10r737[' MergeSort'] < DF10i5114[' MergeSort']), 1, 0)
print(comparar10k)
print("\n")
proporcao1 = comparar10k.value_counts('R7>I5_MergeSort')[0]
print("Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM:", proporcao1)
print("\nDe acordo com a probabilidade proporcional, é indubitável que no MergeSort contendo 10 mil números de teste: ")
print("Intel5 16GBRAM > Ryzen7 8GBRAM")
# Out:
#       R7>I5_MergeSort
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 9995                0
# 9996                0
# 9997                0
# 9998                0
# 9999                0
#
# [10000 rows x 1 columns]
#
#
# Vezes em que Intel5 16GBRAM foi melhor que Ryzen7 8GBRAM: 9957
#
# De acordo com a probabilidade proporcional, é indubitável que no MergeSort contendo 10 mil números de teste:
# Intel5 16GBRAM > Ryzen7 8GBRAM
